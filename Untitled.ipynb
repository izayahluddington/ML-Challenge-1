# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
df = pd.read_csv("bank.csv")
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df_onehot = pd.get_dummies(df[["job","marital","education","default","housing","loan","contact","month","poutcome","deposit"]])
df_onehot

df_new = df_onehot.join(df[["age", "balance","day","duration","campaign","pdays","previous"]])
df_new

y, x = df_new.pop("deposit_no"), df_new
tree = tree.DecisionTreeClassifier()
tree = clf.fit(x, y)
tree.plot_tree(tree)

y1 = df_new.pop("deposit_yes")
tree = tree.DecisionTreeClassifier()
tree = clf.fit(x, y1)
tree.plot_tree(tree)
# Out:
# [Text(153.78465703697185, 213.816, 'X[47] <= 206.5\ngini = 0.499\nsamples = 11162\nvalue = [5873, 5289]'),
#  Text(80.2388787633158, 206.56799999999998, 'X[42] <= 0.5\ngini = 0.328\nsamples = 4524\nvalue = [3587, 937]'),
#  Text(67.80971399519409, 199.32, 'X[35] <= 0.5\ngini = 0.274\nsamples = 4223\nvalue = [3531, 692]'),
#  Text(49.81996613795187, 192.072, 'X[47] <= 123.5\ngini = 0.252\nsamples = 4121\nvalue = [3513, 608]'),
#  Text(28.722015457353482, 184.824, 'X[28] <= 0.5\ngini = 0.123\nsamples = 2238\nvalue = [2091, 147]'),
#  Text(24.572043845596735, 177.576, 'X[38] <= 0.5\ngini = 0.103\nsamples = 2122\nvalue = [2007, 115]'),
#  Text(19.732084410507788, 170.328, 'X[31] <= 0.5\ngini = 0.09\nsamples = 2085\nvalue = [1986, 99]'),
#  Text(14.16303736816104, 163.07999999999998, 'X[39] <= 0.5\ngini = 0.063\nsamples = 1929\nvalue = [1866, 63]'),
#  Text(7.40987323315411, 155.832, 'X[44] <= 24.5\ngini = 0.056\nsamples = 1906\nvalue = [1851, 55]'),
# ...
